# %%
import os
from anthropic import Anthropic
from dotenv import load_dotenv

# %%
load_dotenv()

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))
model ="claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params ={
        "model": model,
        "max_tokens" : 1000,
        "messages" : messages,
        "temperature": temperature 
    }

    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Generate a one movie idea")

answer = chat(messages, temperature=0.0)

# %%
print(answer)
# Out:
# # "The Last Analog"
#
# **Genre:** Sci-fi Thriller
#
# **Logline:** In 2047, when a solar flare wipes out all digital technology worldwide, a reclusive librarian who still knows how to navigate the pre-internet world becomes humanity's most valuable person—and most wanted target.
#
# **Premise:** Maya Chen has spent 20 years as a small-town librarian, teaching forgotten skills like using card catalogs, reading paper maps, and finding information in physical books. When "The Pulse" destroys every computer, phone, and digital device on Earth, civilization collapses overnight. Governments, corporations, and warlords hunt Maya to exploit her analog knowledge, while she races to reach a hidden archive that contains the printed instructions to rebuild society—before those who want to control the new world find it first.
