# %%
# %pip install voyageai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: voyageai in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (0.4.1)
# Requirement already satisfied: ffmpeg-python in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (0.2.0)
# Requirement already satisfied: tenacity in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (9.1.2)
# Requirement already satisfied: tokenizers>=0.14.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (0.22.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (2.13.4)
# Requirement already satisfied: requests in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (2.32.5)
# Requirement already satisfied: pillow in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (11.3.0)
# Requirement already satisfied: numpy in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (2.0.2)
# Requirement already satisfied: aiolimiter in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (1.2.1)
# Requirement already satisfied: aiohttp in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (3.13.5)
# Requirement already satisfied: langchain-text-splitters>=0.3.8 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from voyageai) (0.3.11)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langchain-text-splitters>=0.3.8->voyageai) (0.3.86)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.15.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (4.15.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.4.37)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.11.5)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.28.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.25.0)
# Requirement already satisfied: anyio in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (4.12.1)
# Requirement already satisfied: certifi in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.9)
# Requirement already satisfied: idna in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.16.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->voyageai) (2.46.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->voyageai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->voyageai) (0.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from requests->voyageai) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from requests->voyageai) (3.4.7)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from tokenizers>=0.14.0->voyageai) (1.8.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.5.1)
# Requirement already satisfied: filelock>=3.10.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.19.1)
# Requirement already satisfied: typer in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.23.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2025.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.68.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (0.4.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (6.7.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (1.22.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (5.0.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from aiohttp->voyageai) (26.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.3.1)
# Requirement already satisfied: future in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from ffmpeg-python->voyageai) (0.18.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.0.4)
# Requirement already satisfied: click>=8.0.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (8.1.8)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/neelammore/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.1.2)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(chunks, model="voyage-3-large", input_type="query"):
    is_list = isinstance(chunks, list)
    input = chunks if is_list else [chunks]
    result = client.embed(input, model=model, input_type=input_type)
    return result.embeddings if is_list else result.embeddings[0]

# %%
# VectorIndex implementation
import math
from typing import Optional, Any, List, Dict, Tuple


class VectorIndex:
    def __init__(
        self,
        distance_metric: str = "cosine",
        embedding_fn=None,
    ):
        self.vectors: List[List[float]] = []
        self.documents: List[Dict[str, Any]] = []
        self._vector_dim: Optional[int] = None
        if distance_metric not in ["cosine", "euclidean"]:
            raise ValueError("distance_metric must be 'cosine' or 'euclidean'")
        self._distance_metric = distance_metric
        self._embedding_fn = embedding_fn

    def add_document(self, document: Dict[str, Any]):
        if not self._embedding_fn:
            raise ValueError(
                "Embedding function not provided during initialization."
            )
        if not isinstance(document, dict):
            raise TypeError("Document must be a dictionary.")
        if "content" not in document:
            raise ValueError(
                "Document dictionary must contain a 'content' key."
            )

        content = document["content"]
        if not isinstance(content, str):
            raise TypeError("Document 'content' must be a string.")

        vector = self._embedding_fn(content)
        self.add_vector(vector=vector, document=document)

    def search(
        self, query: Any, k: int = 1
    ) -> List[Tuple[Dict[str, Any], float]]:
        if not self.vectors:
            return []

        if isinstance(query, str):
            if not self._embedding_fn:
                raise ValueError(
                    "Embedding function not provided for string query."
                )
            query_vector = self._embedding_fn(query)
        elif isinstance(query, list) and all(
            isinstance(x, (int, float)) for x in query
        ):
            query_vector = query
        else:
            raise TypeError(
                "Query must be either a string or a list of numbers."
            )

        if self._vector_dim is None:
            return []

        if len(query_vector) != self._vector_dim:
            raise ValueError(
                f"Query vector dimension mismatch. Expected {self._vector_dim}, got {len(query_vector)}"
            )

        if k <= 0:
            raise ValueError("k must be a positive integer.")

        if self._distance_metric == "cosine":
            dist_func = self._cosine_distance
        else:
            dist_func = self._euclidean_distance

        distances = []
        for i, stored_vector in enumerate(self.vectors):
            distance = dist_func(query_vector, stored_vector)
            distances.append((distance, self.documents[i]))

        distances.sort(key=lambda item: item[0])

        return [(doc, dist) for dist, doc in distances[:k]]

    def add_vector(self, vector, document: Dict[str, Any]):
        if not isinstance(vector, list) or not all(
            isinstance(x, (int, float)) for x in vector
        ):
            raise TypeError("Vector must be a list of numbers.")
        if not isinstance(document, dict):
            raise TypeError("Document must be a dictionary.")
        if "content" not in document:
            raise ValueError(
                "Document dictionary must contain a 'content' key."
            )

        if not self.vectors:
            self._vector_dim = len(vector)
        elif len(vector) != self._vector_dim:
            raise ValueError(
                f"Inconsistent vector dimension. Expected {self._vector_dim}, got {len(vector)}"
            )

        self.vectors.append(list(vector))
        self.documents.append(document)

    def _euclidean_distance(
        self, vec1: List[float], vec2: List[float]
    ) -> float:
        if len(vec1) != len(vec2):
            raise ValueError("Vectors must have the same dimension")
        return math.sqrt(sum((p - q) ** 2 for p, q in zip(vec1, vec2)))

    def _dot_product(self, vec1: List[float], vec2: List[float]) -> float:
        if len(vec1) != len(vec2):
            raise ValueError("Vectors must have the same dimension")
        return sum(p * q for p, q in zip(vec1, vec2))

    def _magnitude(self, vec: List[float]) -> float:
        return math.sqrt(sum(x * x for x in vec))

    def _cosine_distance(self, vec1: List[float], vec2: List[float]) -> float:
        if len(vec1) != len(vec2):
            raise ValueError("Vectors must have the same dimension")

        mag1 = self._magnitude(vec1)
        mag2 = self._magnitude(vec2)

        if mag1 == 0 and mag2 == 0:
            return 0.0
        elif mag1 == 0 or mag2 == 0:
            return 1.0

        dot_prod = self._dot_product(vec1, vec2)
        cosine_similarity = dot_prod / (mag1 * mag2)
        cosine_similarity = max(-1.0, min(1.0, cosine_similarity))

        return 1.0 - cosine_similarity

    def __len__(self) -> int:
        return len(self.vectors)

    def __repr__(self) -> str:
        has_embed_fn = "Yes" if self._embedding_fn else "No"
        return f"VectorIndex(count={len(self)}, dim={self._vector_dim}, metric='{self._distance_metric}', has_embedding_fn='{has_embed_fn}')"

# %%
with open("./report.md", "r") as f:
    text = f.read()

# %%
# 1. Chunk the text by section
chunks = chunk_by_section(text)

# %%
# 2. Generate embeddings for each chunk

embeddings = generate_embedding(chunks)

# %%
# 3. Create a vector store and add each embedding to it
# Note: converted to a bulk operation to avoid rate limiting errors from VoyageAI
store = VectorIndex()
store.add_documents([{"content": chunk} for chunk in chunks])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 4
#       1 # 3. Create a vector store and add each embedding to it
#       2 # Note: converted to a bulk operation to avoid rate limiting errors from VoyageAI
#       3 store = VectorIndex()
# ----> 4 store.add_documents([{"content": chunk} for chunk in chunks])
#
# AttributeError: 'VectorIndex' object has no attribute 'add_documents'

# %%
# 4. Some time later, a user will ask a question. Generate an embedding for it

user_embedding = generate_embedding("What did he software engineering dept do last year")

# %%
# 5. Search the store with the embedding, find the 2 most relevant chunks

results = store.search(user_embedding,2)

for doc, distance in results:
    print(distance, "\n", doc["content"][0:200], "\n")
